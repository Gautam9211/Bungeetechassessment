# %%
import pandas as pd 
url = 'https://raw.githubusercontent.com/Bungeetech/internship-test2/master/input/question-3/main.csv'
df = pd.read_csv(url,index_col=0)
df.head()
# Out:
#                 Goals  Shots on target  Shots off target Shooting Accuracy  \
# Team
# Croatia             4               13                12             51.9%
# Czech Republic      4               13                18             41.9%
# Denmark             4               10                10             50.0%
# England             5               11                18             50.0%
# France              3               22                24             37.9%
#
#                % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  \
# Team
# Croatia                   16.0%                          32             0
# Czech Republic            12.9%                          39             0
# Denmark                   20.0%                          27             1
# England                   17.2%                          40             0
# France                     6.5%                          65             1
#
# ...

# %%
data = df.loc[:,['Yellow Cards',"Red Cards"]]

# %%
data.sort_values(by=["Red Cards",'Yellow Cards'], ascending=False,inplace = True)

# %%
data.to_csv(r'C:\Users\Gautam Aggarwal\Desktop\bungteeTech\output\answer3\output3.csv')
